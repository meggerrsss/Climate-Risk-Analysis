# %%
import xarray as xr
import xclim

# %%
wb_AWI_CM_ssp126 = xclim.indices.water_budget(
    pr=pr_AWI_CM_ssp126.pr, tas = tas_AWI_CM_ssp126.tas, method="MB05")

# %%
SPEI_AWI_CM_ssp126 = xclim.indices.standardized_precipitation_evapotranspiration_index(
    wb=wb_AWI_CM_ssp126,freq='MS',window=12)
