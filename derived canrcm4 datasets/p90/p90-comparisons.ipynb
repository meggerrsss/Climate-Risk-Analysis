# %%
import xarray as xr
look1 = xr.open_dataset(r"C:\Data\sfcWindmax\historical\rasters\sfcWindmax-anwindgust63_CanRCM4_historical_p90sim_1976-2005_annp90sim_30yavg.nc")
look2 = xr.open_dataset(r"C:\Data\sfcWindmax\historical\rasters\sfcWindmax-anwindgust63_CanRCM4_historical_p90sim_1976-2005_annp90sim_30yavg.nc")
look3 = xr.open_dataset(r"C:\Data\sfcWindmax\historical\rasters\sfcWindmax-anwindgust63_CanRCM4_historical_1976-2005_annmean_30yavg.nc")
look4 = xr.open_dataset(r"C:\Data\sfcWindmax\historical\rasters\sfcWindmax-anwindgust63_CanRCM4_historical_1976-2005_annmean_30yp90.nc") # one in sharepoint
look5 = xr.open_dataset(r"C:\Data\sfcWindmax\historical\rasters\sfcWindmax-anwindgust63_CanRCM4_historical_1976-2005_annmean_30yp10.nc")

# %%
ds = look3
var = list(ds.data_vars)[0]
ds[var].plot()

# %%
var = list(look2.data_vars)[0]
look2[var].plot()

# %%
var = list(look3.data_vars)[0]
look3[var].plot()

# %%
delta = look2[var]-look1[var]
delta.plot()
