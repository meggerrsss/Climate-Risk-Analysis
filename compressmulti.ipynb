# %%
import xarray as xr
import os

# %%
folder = r"C:\Data\zos\historical\originals\*.nc"
outname = folder.replace("*","compressed")
ds = xr.open_mfdataset(folder, combine='by_coords')
# Out:
# C:\Users\CAMG038492\AppData\Local\Temp\ipykernel_32568\2385618098.py:3: SerializationWarning: Unable to decode time axis into full numpy.datetime64[ns] objects, continuing using cftime.datetime objects instead, reason: dates out of range. To silence this warning use a coarser resolution 'time_unit' or specify 'use_cftime=True'.
#   ds = xr.open_mfdataset(folder, combine='by_coords')

# %%
ds = ds.compute()
#ds.to_netcdf(outname)
print(f"exported {outname} to {folder}")
# Out:
# c:\Users\CAMG038492\AppData\Local\miniforge3\envs\climate\Lib\site-packages\dask\array\core.py:141: SerializationWarning: Unable to decode time axis into full numpy.datetime64[ns] objects, continuing using cftime.datetime objects instead, reason: dates out of range. To silence this warning use a coarser resolution 'time_unit' or specify 'use_cftime=True'.
#   c = np.asarray(c)
# exported C:\Data\flashrate\ssp585\originals\v1 CESM2\compressed.nc to C:\Data\flashrate\ssp585\originals\v1 CESM2\*.nc
